# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39aed027b0b67abc289439e406a0ede4

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | yar-sale
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | vanavara
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | kaitangata
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | belmopan
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | khandyga
# Processing Record 18 of Set 1 | fort nelson
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | behat
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | san quintin
# Processing Record 27 of Set 1 | dali
# Processing Record 28 of Set 1 | kaoma
# Processing Record 29 of Set 1 | lata
# Processing Record 30 of Set 1 | padang
# Processing Record 31 of Set 1 | yulara
# Processing Record 32 of Set 1 | matagami
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | half moon bay
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | cap-aux-meules
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | burgos
# Processing Record 41 of Set 1 | maragogi
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | alihe
# Processing Record 44 of Set 1 | jumla
# Processing Record 45 of Set 1 | shunyi
# Processing Record 46 of Set 1 | veraval
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | ternate
# Processing Record 50 of Set 1 | misratah
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | hambantota
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | akcakoca
# Processing Record 7 of Set 2 | palmerston
# Processing Record 8 of Set 2 | piracanjuba
# Processing Record 9 of Set 2 | laguna
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | burnie
# Processing Record 12 of Set 2 | zlobin
# Processing Record 13 of Set 2 | kikwit
# Processing Record 14 of Set 2 | namibe
# Processing Record 15 of Set 2 | tingi
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | walvis bay
# Processing Record 18 of Set 2 | karratha
# Processing Record 19 of Set 2 | salair
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | samagaltay
# Processing Record 25 of Set 2 | hirara
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | xuddur
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | stanford
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | hofn
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | barreiras
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | tadine
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | komsomolskiy
# Processing Record 45 of Set 2 | kormilovka
# Processing Record 46 of Set 2 | krupanj
# Processing Record 47 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | galena park
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | mahudha
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | musoma
# Processing Record 6 of Set 3 | aquiraz
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | tirumullaivasal
# Processing Record 10 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 3 | digha
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | haderslev
# Processing Record 14 of Set 3 | college
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | copiapo
# Processing Record 18 of Set 3 | teacapan
# Processing Record 19 of Set 3 | coahuayana
# Processing Record 20 of Set 3 | quba
# Processing Record 21 of Set 3 | tabuk
# Processing Record 22 of Set 3 | yumen
# Processing Record 23 of Set 3 | kumo
# Processing Record 24 of Set 3 | marsh harbour
# Processing Record 25 of Set 3 | otawara
# Processing Record 26 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | rongcheng
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | viljoenskroon
# Processing Record 31 of Set 3 | nizhniy odes
# Processing Record 32 of Set 3 | farmington
# Processing Record 33 of Set 3 | alexandria
# Processing Record 34 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 3 | namatanai
# Processing Record 38 of Set 3 | polunochnoye
# Processing Record 39 of Set 3 | kudymkar
# Processing Record 40 of Set 3 | cartagena del chaira
# Processing Record 41 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 3 | ilo
# Processing Record 43 of Set 3 | inta
# Processing Record 44 of Set 3 | japura
# Processing Record 45 of Set 3 | ampanihy
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | vardo
# Processing Record 48 of Set 3 | khandagayty
# Processing Record 49 of Set 3 | nyurba
# Processing Record 50 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | vagur
# Processing Record 3 of Set 4 | kargil
# Processing Record 4 of Set 4 | thunder bay
# Processing Record 5 of Set 4 | ulladulla
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | nome
# Processing Record 8 of Set 4 | morros
# Processing Record 9 of Set 4 | arraial do cabo
# Processing Record 10 of Set 4 | port-cartier
# Processing Record 11 of Set 4 | groningen
# Processing Record 12 of Set 4 | talakan
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | schattdorf
# Processing Record 15 of Set 4 | honningsvag
# Processing Record 16 of Set 4 | quatre cocos
# Processing Record 17 of Set 4 | aswan
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | manokwari
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | chuy
# Processing Record 23 of Set 4 | portland
# Processing Record 24 of Set 4 | potosi
# Processing Record 25 of Set 4 | bambanglipuro
# Processing Record 26 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | gizo
# Processing Record 29 of Set 4 | port hedland
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | ostrovnoy
# Processing Record 32 of Set 4 | cedeno
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | taltal
# Processing Record 35 of Set 4 | zhigansk
# Processing Record 36 of Set 4 | northam
# Processing Record 37 of Set 4 | bat yam
# Processing Record 38 of Set 4 | whitecourt
# Processing Record 39 of Set 4 | salalah
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | touros
# Processing Record 42 of Set 4 | ferrol
# Processing Record 43 of Set 4 | bluff
# Processing Record 44 of Set 4 | vila velha
# Processing Record 45 of Set 4 | kawalu
# Processing Record 46 of Set 4 | ponta do sol
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | alice springs
# Processing Record 49 of Set 4 | camana
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | ayni
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | broome
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | macklin
# Processing Record 7 of Set 5 | chokurdakh
# Processing Record 8 of Set 5 | yichang
# Processing Record 9 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 5 | saint andrews
# Processing Record 11 of Set 5 | cap malheureux
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | faanui
# Processing Record 14 of Set 5 | huarmey
# Processing Record 15 of Set 5 | uige
# Processing Record 16 of Set 5 | armizonskoye
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | mutoko
# Processing Record 19 of Set 5 | inhambane
# Processing Record 20 of Set 5 | wamba
# Processing Record 21 of Set 5 | francistown
# Processing Record 22 of Set 5 | altay
# Processing Record 23 of Set 5 | havoysund
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | okhotsk
# Processing Record 26 of Set 5 | kijini
# Processing Record 27 of Set 5 | dingle
# Processing Record 28 of Set 5 | ejido
# Processing Record 29 of Set 5 | estelle
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | ola
# Processing Record 32 of Set 5 | riviere-au-renard
# Processing Record 33 of Set 5 | kumluca
# Processing Record 34 of Set 5 | olafsvik
# Processing Record 35 of Set 5 | mao
# Processing Record 36 of Set 5 | harper
# Processing Record 37 of Set 5 | thiruvananthapuram
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | jacareacanga
# Processing Record 40 of Set 5 | coihaique
# Processing Record 41 of Set 5 | caravelas
# Processing Record 42 of Set 5 | carballo
# Processing Record 43 of Set 5 | fairbanks
# Processing Record 44 of Set 5 | praia da vitoria
# Processing Record 45 of Set 5 | whitehorse
# Processing Record 46 of Set 5 | aklavik
# Processing Record 47 of Set 5 | qaqortoq
# Processing Record 48 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 5 | najran
# Processing Record 50 of Set 5 | bredasdorp
# Processing Record 1 of Set 6 | dehloran
# Processing Record 2 of Set 6 | eyrarbakki
# Processing Record 3 of Set 6 | toledo
# Processing Record 4 of Set 6 | lavrentiya
# Processing Record 5 of Set 6 | pevek
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | nelson bay
# Processing Record 8 of Set 6 | lipari
# Processing Record 9 of Set 6 | calabozo
# Processing Record 10 of Set 6 | te anau
# Processing Record 11 of Set 6 | cidreira
# Processing Record 12 of Set 6 | morbegno
# Processing Record 13 of Set 6 | severnyy
# Processing Record 14 of Set 6 | ahlat
# Processing Record 15 of Set 6 | chapais
# Processing Record 16 of Set 6 | kyren
# Processing Record 17 of Set 6 | panjab
# Processing Record 18 of Set 6 | tuatapere
# Processing Record 19 of Set 6 | necochea
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | campo do brito
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 6 | burica
# City not found. Skipping...
# Processing Record 25 of Set 6 | eureka
# Processing Record 26 of Set 6 | husavik
# Processing Record 27 of Set 6 | makakilo city
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | vyshestebliyevskaya
# Processing Record 30 of Set 6 | jepelacio
# Processing Record 31 of Set 6 | pedasi
# Processing Record 32 of Set 6 | klaksvik
# Processing Record 33 of Set 6 | mackay
# Processing Record 34 of Set 6 | mehamn
# Processing Record 35 of Set 6 | amod
# Processing Record 36 of Set 6 | vao
# Processing Record 37 of Set 6 | stornoway
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | marsa matruh
# Processing Record 40 of Set 6 | atar
# Processing Record 41 of Set 6 | tawzar
# City not found. Skipping...
# Processing Record 42 of Set 6 | bengkulu
# Processing Record 43 of Set 6 | goderich
# Processing Record 44 of Set 6 | sing buri
# Processing Record 45 of Set 6 | presidente epitacio
# Processing Record 46 of Set 6 | camacha
# Processing Record 47 of Set 6 | umm lajj
# Processing Record 48 of Set 6 | maarianhamina
# Processing Record 49 of Set 6 | xichang
# Processing Record 50 of Set 6 | dunedin
# Processing Record 1 of Set 7 | ossora
# Processing Record 2 of Set 7 | homer
# Processing Record 3 of Set 7 | kalmunai
# Processing Record 4 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 7 | sitka
# Processing Record 6 of Set 7 | mahibadhoo
# Processing Record 7 of Set 7 | svay rieng
# Processing Record 8 of Set 7 | codrington
# Processing Record 9 of Set 7 | zambezi
# Processing Record 10 of Set 7 | nizwa
# Processing Record 11 of Set 7 | beloha
# Processing Record 12 of Set 7 | sao filipe
# Processing Record 13 of Set 7 | merritt island
# Processing Record 14 of Set 7 | doha
# Processing Record 15 of Set 7 | fare
# Processing Record 16 of Set 7 | marovoay
# Processing Record 17 of Set 7 | mayo
# Processing Record 18 of Set 7 | karpathos
# Processing Record 19 of Set 7 | balkhash
# Processing Record 20 of Set 7 | morondava
# Processing Record 21 of Set 7 | langres
# Processing Record 22 of Set 7 | san miguel el alto
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | asau
# Processing Record 27 of Set 7 | havre-saint-pierre
# Processing Record 28 of Set 7 | tabou
# Processing Record 29 of Set 7 | goure
# Processing Record 30 of Set 7 | nuuk
# Processing Record 31 of Set 7 | chapada dos guimaraes
# Processing Record 32 of Set 7 | kruisfontein
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | werda
# Processing Record 35 of Set 7 | dagda
# Processing Record 36 of Set 7 | deputatskiy
# Processing Record 37 of Set 7 | khatanga
# Processing Record 38 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 7 | siocon
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | yaring
# Processing Record 42 of Set 7 | cam ranh
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | amapa
# Processing Record 45 of Set 7 | cedar city
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | tongsa
# City not found. Skipping...
# Processing Record 48 of Set 7 | basqal
# Processing Record 49 of Set 7 | andijon
# Processing Record 50 of Set 7 | mandalgovi
# Processing Record 1 of Set 8 | businga
# Processing Record 2 of Set 8 | sandur
# Processing Record 3 of Set 8 | smidovich
# Processing Record 4 of Set 8 | kanniyakumari
# Processing Record 5 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 8 | riyadh
# Processing Record 7 of Set 8 | paita
# Processing Record 8 of Set 8 | miles city
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | lokosovo
# Processing Record 11 of Set 8 | norman wells
# Processing Record 12 of Set 8 | falmouth
# Processing Record 13 of Set 8 | rindal
# Processing Record 14 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 15 of Set 8 | norton
# Processing Record 16 of Set 8 | kutum
# Processing Record 17 of Set 8 | daru
# Processing Record 18 of Set 8 | el rosario
# Processing Record 19 of Set 8 | araouane
# Processing Record 20 of Set 8 | casino
# Processing Record 21 of Set 8 | aasiaat
# Processing Record 22 of Set 8 | cherskiy
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | margate
# Processing Record 25 of Set 8 | acajutla
# Processing Record 26 of Set 8 | biak
# Processing Record 27 of Set 8 | srivardhan
# Processing Record 28 of Set 8 | sorland
# Processing Record 29 of Set 8 | iqaluit
# Processing Record 30 of Set 8 | charters towers
# Processing Record 31 of Set 8 | santa rosa
# Processing Record 32 of Set 8 | belyy yar
# Processing Record 33 of Set 8 | denpasar
# Processing Record 34 of Set 8 | akureyri
# Processing Record 35 of Set 8 | novyy svit
# Processing Record 36 of Set 8 | prince rupert
# Processing Record 37 of Set 8 | ust-barguzin
# Processing Record 38 of Set 8 | kondratovo
# Processing Record 39 of Set 8 | ntcheu
# Processing Record 40 of Set 8 | smithers
# Processing Record 41 of Set 8 | martapura
# Processing Record 42 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 43 of Set 8 | tecoanapa
# Processing Record 44 of Set 8 | hobyo
# Processing Record 45 of Set 8 | ixtapa
# Processing Record 46 of Set 8 | tierralta
# Processing Record 47 of Set 8 | dwarka
# Processing Record 48 of Set 8 | ryotsu
# Processing Record 49 of Set 8 | khadyzhensk
# Processing Record 50 of Set 8 | gazli
# Processing Record 1 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 9 | onega
# Processing Record 3 of Set 9 | luba
# Processing Record 4 of Set 9 | altamont
# Processing Record 5 of Set 9 | lebu
# Processing Record 6 of Set 9 | guerande
# Processing Record 7 of Set 9 | matamoros
# Processing Record 8 of Set 9 | bilma
# Processing Record 9 of Set 9 | shache
# Processing Record 10 of Set 9 | aginskoye
# Processing Record 11 of Set 9 | nuevitas
# Processing Record 12 of Set 9 | rio gallegos
# Processing Record 13 of Set 9 | tecpan
# Processing Record 14 of Set 9 | kiruna
# Processing Record 15 of Set 9 | kifri
# Processing Record 16 of Set 9 | shelburne
# Processing Record 17 of Set 9 | miracema do tocantins
# Processing Record 18 of Set 9 | pangnirtung
# Processing Record 19 of Set 9 | hualmay
# Processing Record 20 of Set 9 | yazd
# Processing Record 21 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 22 of Set 9 | cambyreta
# City not found. Skipping...
# Processing Record 23 of Set 9 | chicama
# Processing Record 24 of Set 9 | kharp
# Processing Record 25 of Set 9 | kahului
# Processing Record 26 of Set 9 | waipawa
# Processing Record 27 of Set 9 | sabang
# Processing Record 28 of Set 9 | benjamin constant
# Processing Record 29 of Set 9 | chengde
# Processing Record 30 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 9 | harnosand
# Processing Record 32 of Set 9 | billings
# Processing Record 33 of Set 9 | kangaatsiaq
# Processing Record 34 of Set 9 | puerto escondido
# Processing Record 35 of Set 9 | turukhansk
# Processing Record 36 of Set 9 | broken hill
# Processing Record 37 of Set 9 | obo
# Processing Record 38 of Set 9 | pontes e lacerda
# Processing Record 39 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 9 | vredendal
# Processing Record 41 of Set 9 | oda
# Processing Record 42 of Set 9 | harer
# Processing Record 43 of Set 9 | clyde river
# Processing Record 44 of Set 9 | oxford
# Processing Record 45 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | bairiki
# Processing Record 47 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 9 | waw
# Processing Record 49 of Set 9 | san vicente
# Processing Record 50 of Set 9 | labuan
# Processing Record 1 of Set 10 | giyon
# Processing Record 2 of Set 10 | tazovskiy
# Processing Record 3 of Set 10 | abu zabad
# Processing Record 4 of Set 10 | san cristobal
# Processing Record 5 of Set 10 | mataram
# Processing Record 6 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 7 of Set 10 | nhulunbuy
# Processing Record 8 of Set 10 | dedovichi
# Processing Record 9 of Set 10 | slave lake
# Processing Record 10 of Set 10 | tazmalt
# Processing Record 11 of Set 10 | avanigadda
# Processing Record 12 of Set 10 | beringovskiy
# Processing Record 13 of Set 10 | the valley
# Processing Record 14 of Set 10 | barcelos
# Processing Record 15 of Set 10 | esmeraldas
# Processing Record 16 of Set 10 | port augusta
# Processing Record 17 of Set 10 | la ronge
# Processing Record 18 of Set 10 | asyut
# Processing Record 19 of Set 10 | vuktyl
# Processing Record 20 of Set 10 | rovaniemi
# Processing Record 21 of Set 10 | landerneau
# Processing Record 22 of Set 10 | vostok
# Processing Record 23 of Set 10 | ayan
# Processing Record 24 of Set 10 | srednekolymsk
# Processing Record 25 of Set 10 | anadyr
# Processing Record 26 of Set 10 | svetlogorsk
# Processing Record 27 of Set 10 | palana
# Processing Record 28 of Set 10 | seybaplaya
# Processing Record 29 of Set 10 | la romana
# Processing Record 30 of Set 10 | quang ngai
# Processing Record 31 of Set 10 | notodden
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | ekhabi
# Processing Record 34 of Set 10 | tateyama
# Processing Record 35 of Set 10 | ylivieska
# Processing Record 36 of Set 10 | buchanan
# Processing Record 37 of Set 10 | bathsheba
# Processing Record 38 of Set 10 | price
# Processing Record 39 of Set 10 | guanica
# Processing Record 40 of Set 10 | ngudu
# Processing Record 41 of Set 10 | wagar
# Processing Record 42 of Set 10 | bowen
# Processing Record 43 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 10 | rawson
# Processing Record 45 of Set 10 | imbituba
# Processing Record 46 of Set 10 | ihosy
# Processing Record 47 of Set 10 | sakakah
# Processing Record 48 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 10 | derzhavinsk
# Processing Record 50 of Set 10 | kaura namoda
# Processing Record 1 of Set 11 | semporna
# Processing Record 2 of Set 11 | edgewater
# Processing Record 3 of Set 11 | saint-augustin
# Processing Record 4 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 11 | zyryanka
# Processing Record 6 of Set 11 | puerto rondon
# Processing Record 7 of Set 11 | alberton
# Processing Record 8 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 11 | chardara
# Processing Record 10 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 11 | seoul
# Processing Record 12 of Set 11 | morehead
# Processing Record 13 of Set 11 | hue
# Processing Record 14 of Set 11 | aykhal
# Processing Record 15 of Set 11 | urusha
# Processing Record 16 of Set 11 | krasnokamensk
# Processing Record 17 of Set 11 | baiyin
# Processing Record 18 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 11 | coquimbo
# Processing Record 20 of Set 11 | khunti
# Processing Record 21 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 11 | toora-khem
# Processing Record 23 of Set 11 | starokostyantyniv
# Processing Record 24 of Set 11 | maple creek
# Processing Record 25 of Set 11 | noshiro
# Processing Record 26 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 11 | corumba
# Processing Record 28 of Set 11 | lasa
# Processing Record 29 of Set 11 | rayagada
# Processing Record 30 of Set 11 | madanapalle
# Processing Record 31 of Set 11 | talcahuano
# Processing Record 32 of Set 11 | yakeshi
# Processing Record 33 of Set 11 | wukari
# Processing Record 34 of Set 11 | hervey bay
# Processing Record 35 of Set 11 | poum
# Processing Record 36 of Set 11 | nizhniy kuranakh
# Processing Record 37 of Set 11 | acapulco
# Processing Record 38 of Set 11 | tayu
# Processing Record 39 of Set 11 | kyabram
# Processing Record 40 of Set 11 | popondetta
# Processing Record 41 of Set 11 | pacific grove
# Processing Record 42 of Set 11 | tyler
# Processing Record 43 of Set 11 | hargeysa
# Processing Record 44 of Set 11 | puerto lempira
# Processing Record 45 of Set 11 | mezen
# Processing Record 46 of Set 11 | nishihara
# Processing Record 47 of Set 11 | ewa beach
# Processing Record 48 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 11 | rumilly
# Processing Record 50 of Set 11 | west plains
# Processing Record 1 of Set 12 | beirut
# Processing Record 2 of Set 12 | impfondo
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | murdochville
# Processing Record 5 of Set 12 | kasangulu
# Processing Record 6 of Set 12 | westport
# Processing Record 7 of Set 12 | dongsheng
# Processing Record 8 of Set 12 | victoria
# Processing Record 9 of Set 12 | goundam
# Processing Record 10 of Set 12 | usinsk
# Processing Record 11 of Set 12 | rawlins
# Processing Record 12 of Set 12 | tessalit
# Processing Record 13 of Set 12 | mareeba
# Processing Record 14 of Set 12 | kautokeino
# Processing Record 15 of Set 12 | asopos
# Processing Record 16 of Set 12 | fallon
# Processing Record 17 of Set 12 | vila franca do campo
# Processing Record 18 of Set 12 | naryan-mar
# Processing Record 19 of Set 12 | los banos
# Processing Record 20 of Set 12 | cabedelo
# Processing Record 21 of Set 12 | summerside
# Processing Record 22 of Set 12 | mbandaka
# Processing Record 23 of Set 12 | itoman
# Processing Record 24 of Set 12 | mecca
# Processing Record 25 of Set 12 | silvania
# Processing Record 26 of Set 12 | marrakesh
# Processing Record 27 of Set 12 | kingston
# Processing Record 28 of Set 12 | barkly west
# Processing Record 29 of Set 12 | poya
# Processing Record 30 of Set 12 | kirakira
# Processing Record 31 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 12 | abay
# Processing Record 33 of Set 12 | cayenne
# Processing Record 34 of Set 12 | faya
# Processing Record 35 of Set 12 | kloulklubed
# Processing Record 36 of Set 12 | moerai
# Processing Record 37 of Set 12 | thinadhoo
# Processing Record 38 of Set 12 | sur
# Processing Record 39 of Set 12 | nizhneshilovka
# City not found. Skipping...
# Processing Record 40 of Set 12 | biga
# Processing Record 41 of Set 12 | cairns
# Processing Record 42 of Set 12 | olinda
# Processing Record 43 of Set 12 | nabire
# Processing Record 44 of Set 12 | oktyabrskoye
# Processing Record 45 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | moundsville
# Processing Record 47 of Set 12 | camocim
# Processing Record 48 of Set 12 | mayor pablo lagerenza
# Processing Record 49 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 12 | boddam
# Processing Record 1 of Set 13 | sandwick
# Processing Record 2 of Set 13 | vestmanna
# Processing Record 3 of Set 13 | road town
# Processing Record 4 of Set 13 | ajdabiya
# Processing Record 5 of Set 13 | viedma
# Processing Record 6 of Set 13 | wanning
# Processing Record 7 of Set 13 | oeiras do para
# Processing Record 8 of Set 13 | tonder
# Processing Record 9 of Set 13 | kongolo
# Processing Record 10 of Set 13 | zholymbet
# Processing Record 11 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 13 | strezhevoy
# Processing Record 13 of Set 13 | richards bay
# Processing Record 14 of Set 13 | ponot
# Processing Record 15 of Set 13 | lodja
# Processing Record 16 of Set 13 | batemans bay
# Processing Record 17 of Set 13 | sao joao da barra
# Processing Record 18 of Set 13 | mandan
# Processing Record 19 of Set 13 | saint-georges
# Processing Record 20 of Set 13 | okha
# Processing Record 21 of Set 13 | lahan
# Processing Record 22 of Set 13 | casa grande
# Processing Record 23 of Set 13 | brodokalmak
# Processing Record 24 of Set 13 | waddan
# Processing Record 25 of Set 13 | capoterra
# Processing Record 26 of Set 13 | yeovil
# Processing Record 27 of Set 13 | arlit
# Processing Record 28 of Set 13 | abrau-dyurso
# Processing Record 29 of Set 13 | simao
# Processing Record 30 of Set 13 | ati
# Processing Record 31 of Set 13 | ponta delgada
# Processing Record 32 of Set 13 | do gonbadan
# Processing Record 33 of Set 13 | novyy urgal
# Processing Record 34 of Set 13 | port hardy
# Processing Record 35 of Set 13 | ndungu
# Processing Record 36 of Set 13 | kieta
# Processing Record 37 of Set 13 | vacaria
# Processing Record 38 of Set 13 | beidao
# Processing Record 39 of Set 13 | tonj
# Processing Record 40 of Set 13 | goya
# Processing Record 41 of Set 13 | orangeburg
# Processing Record 42 of Set 13 | roma
# Processing Record 43 of Set 13 | udachnyy
# Processing Record 44 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 13 | puerto baquerizo moreno
# Processing Record 46 of Set 13 | sept-iles
# Processing Record 47 of Set 13 | posse
# Processing Record 48 of Set 13 | baft
# Processing Record 49 of Set 13 | neyshabur
# Processing Record 50 of Set 13 | sao jose da coroa grande
# Processing Record 1 of Set 14 | nanpiao
# Processing Record 2 of Set 14 | caxias
# Processing Record 3 of Set 14 | jaciara
# Processing Record 4 of Set 14 | semaria
# Processing Record 5 of Set 14 | gladstone
# Processing Record 6 of Set 14 | columbus
# Processing Record 7 of Set 14 | korla
# Processing Record 8 of Set 14 | dumas
# Processing Record 9 of Set 14 | saint-louis
# Processing Record 10 of Set 14 | ambam
# Processing Record 11 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | el playon
# Processing Record 13 of Set 14 | port lincoln
# Processing Record 14 of Set 14 | manaure
# Processing Record 15 of Set 14 | roald
# Processing Record 16 of Set 14 | zhezkazgan
# Processing Record 17 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 18 of Set 14 | swift current
# Processing Record 19 of Set 14 | charyshskoye
# Processing Record 20 of Set 14 | mikkeli
# Processing Record 21 of Set 14 | horasan
# Processing Record 22 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 14 | los llanos de aridane
# Processing Record 24 of Set 14 | talas
# Processing Record 25 of Set 14 | khandbari
# Processing Record 26 of Set 14 | santiago del estero
# Processing Record 27 of Set 14 | tsiroanomandidy
# Processing Record 28 of Set 14 | tabas
# Processing Record 29 of Set 14 | warmbad
# Processing Record 30 of Set 14 | agadez
# Processing Record 31 of Set 14 | assiniboia
# Processing Record 32 of Set 14 | emba
# Processing Record 33 of Set 14 | lebedinyy
# Processing Record 34 of Set 14 | dicabisagan
# Processing Record 35 of Set 14 | esil
# Processing Record 36 of Set 14 | dakar
# Processing Record 37 of Set 14 | paamiut
# Processing Record 38 of Set 14 | jiamusi
# Processing Record 39 of Set 14 | george
# Processing Record 40 of Set 14 | zakamensk
# Processing Record 41 of Set 14 | shenjiamen
# Processing Record 42 of Set 14 | mandera
# Processing Record 43 of Set 14 | evensk
# Processing Record 44 of Set 14 | bogorodskoye
# Processing Record 45 of Set 14 | pierre
# Processing Record 46 of Set 14 | uinskoye
# Processing Record 47 of Set 14 | sinnamary
# Processing Record 48 of Set 14 | den helder
# Processing Record 49 of Set 14 | black forest
# Processing Record 50 of Set 14 | ahuimanu
# Processing Record 1 of Set 15 | baherden
# Processing Record 2 of Set 15 | kirensk
# Processing Record 3 of Set 15 | labuhan
# Processing Record 4 of Set 15 | basco
# Processing Record 5 of Set 15 | puxinana
# Processing Record 6 of Set 15 | fenoarivo
# Processing Record 7 of Set 15 | tambopata
# Processing Record 8 of Set 15 | hickory
# Processing Record 9 of Set 15 | amnat charoen
# Processing Record 10 of Set 15 | lusambo
# Processing Record 11 of Set 15 | pimentel
# Processing Record 12 of Set 15 | meulaboh
# Processing Record 13 of Set 15 | ramganj
# Processing Record 14 of Set 15 | tarancon
# Processing Record 15 of Set 15 | vanersborg
# Processing Record 16 of Set 15 | ahipara
# Processing Record 17 of Set 15 | tepla
# Processing Record 18 of Set 15 | bolshaya irba
# City not found. Skipping...
# Processing Record 19 of Set 15 | port blair
# Processing Record 20 of Set 15 | pivijay
# Processing Record 21 of Set 15 | kaz
# Processing Record 22 of Set 15 | moranbah
# Processing Record 23 of Set 15 | zadonsk
# Processing Record 24 of Set 15 | ambanja
# Processing Record 25 of Set 15 | grande prairie
# Processing Record 26 of Set 15 | ye
# City not found. Skipping...
# Processing Record 27 of Set 15 | araxa
# Processing Record 28 of Set 15 | pringsewu
# Processing Record 29 of Set 15 | bereda
# Processing Record 30 of Set 15 | subtanjalla
# Processing Record 31 of Set 15 | cayon
# Processing Record 32 of Set 15 | santiago
# Processing Record 33 of Set 15 | zajas
# Processing Record 34 of Set 15 | manono
# Processing Record 35 of Set 15 | batticaloa
# Processing Record 36 of Set 15 | hirson
# Processing Record 37 of Set 15 | chifeng
# Processing Record 38 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 39 of Set 15 | avera
# Processing Record 40 of Set 15 | itarema
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585   55.7679     67.59        69          50
# 1        Yar-Sale  66.8333   70.8333     44.53        69          99
# 2        Hermanus -34.4187   19.2345     54.81        80          40
# 3           Lagoa  39.0500  -27.9833     62.01        78         100
# 4          Hasaki  35.7333  140.8333     64.80        72         100
# 5        Vanavara  60.3400  102.2797     74.41        45          63
# 6         Mataura -46.1927  168.8643     41.49        93         100
# 7    Longyearbyen  78.2186   15.6401     40.84        60          75
# 8     Provideniya  64.3833 -173.3000     35.71        87         100
# 9           Vaini -21.2000 -175.2000     80.76        78          20
#
#    Wind Speed Country Weather Description
# 0       15.75      RE    scattered clouds
# 1       15.03      RU     overcast clouds
# 2       18.59      ZA    scattered clouds
# 3        4.70      PT     overcast clouds
# 4       15.14      JP     overcast clouds
# 5        4.72      RU       broken clouds
# 6       13.82      NZ     overcast clouds
# 7        8.05      SJ       broken clouds
# 8       13.42      RU          light rain
# 9        5.75      TO          few clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      RE -21.3585   55.7679     67.59        69          50
# 1        Yar-Sale      RU  66.8333   70.8333     44.53        69          99
# 2        Hermanus      ZA -34.4187   19.2345     54.81        80          40
# 3           Lagoa      PT  39.0500  -27.9833     62.01        78         100
# 4          Hasaki      JP  35.7333  140.8333     64.80        72         100
# 5        Vanavara      RU  60.3400  102.2797     74.41        45          63
# 6         Mataura      NZ -46.1927  168.8643     41.49        93         100
# 7    Longyearbyen      SJ  78.2186   15.6401     40.84        60          75
# 8     Provideniya      RU  64.3833 -173.3000     35.71        87         100
# 9           Vaini      TO -21.2000 -175.2000     80.76        78          20
#
#    Wind Speed Weather Description
# 0       15.75    scattered clouds
# 1       15.03     overcast clouds
# 2       18.59    scattered clouds
# 3        4.70     overcast clouds
# 4       15.14     overcast clouds
# 5        4.72       broken clouds
# 6       13.82     overcast clouds
# 7        8.05       broken clouds
# 8       13.42          light rain
# 9        5.75          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
